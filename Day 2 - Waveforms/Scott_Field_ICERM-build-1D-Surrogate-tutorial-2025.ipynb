# %% [markdown]
# # Building a 1-dimensional surrogate
#
# ICERM Workshop: Scientific Machine Learning for Gravitational Wave Astronomy
#
# Date: 6/3/2025
#
# Author: Scott Field
#
# **Note**: In addition to the usual Python libraries, you will need rompy and gwsurrogate.
#
# ```bash
# >>> conda create -n icerm python=3.11 "numpy<2.0"
# >>> conda install -c conda-forge gwsurrogate
# >>> conda install -c conda-forge jupyterlab
# >>> pip install forked-rompy
# ```

# %% [markdown]
# # Session goal...
#
# ## Target audience
#
# * Introductory tutorial showing how some of the methods referenced in Carl's talk can be implimented in practice.
# * Assumes people broadly know about gravitational wave models. Maybe even dabbled in surrogate modelling.
#
# ## Problem statement
#
# This notebook describes how to build a simple 1-dimensional surrogate model of your favorite 1-dimensional gravitational-wave model:
#
# \begin{align*}
# h(t, \theta, \phi; q) & = h_+(t, \theta, \phi; q) - \mathrm{i} h_x(t, \theta, \phi; q) \\
# & = \sum_{\ell=2}^{\infty} \sum_{m=-\ell}^{\ell} h^{\ell m}(t;q) {}_{-2}Y_{\ell m} \left(\theta, \phi \right) \, ,
# \end{align*}
#
# Where $\theta$ and $\phi$ are angles for the direction of propagation away from the source, $q$ is the mass ratio and ${}_{-2}Y_{\ell m}$ are the harmonic functions.
#
# We will build a surrogte for the (2,2)-mode
#
# $$h^{22}(t;q)$$
#
#
# Our building strategy will mix different methods according to:
#
# * Align waveforms in time, but not phase
# * SVD basis
# * Empirical interpolant representation
# * Splines to approximate the real/imaginary parts of h(T;q) for T fixed and q variying
#
# While each part has been reported in the litterature (being a mixture of methods considered in https://arxiv.org/abs/1402.4146 and https://arxiv.org/abs/1308.3565), this combination hasn't been considered in a published paper before. This illustrates the flexability of surrogate building.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:21
# 🔁 Restarting kernel...

# %%
# After kernel restart, run again to ensure Conda is active
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -n icerm python=3.11 "numpy<2.0"
# !conda install -c conda-forge gwsurrogate
# !conda install -c conda-forge jupyterlab
# !pip install forked-rompy
# Out:
# Streaming output truncated to the last 5000 lines.
# tk-8.6.13            | 3.1 MB    | :   1% 0.009974418635798569/1 [00:00<00:10, 10.71s/it]
#
# python-3.11.12       | 29.1 MB   | :   0% 0.0005363802244363621/1 [00:00<04:36, 276.31s/it]
# numpy-1.26.4         | 7.7 MB    | :  38% 0.37578494127740397/1 [00:00<00:00,  2.17it/s]
#
#
# libstdcxx-15.1.0     | 3.7 MB    | :  27% 0.26870338551976947/1 [00:00<00:00,  1.51it/s]
#
#
#
# tk-8.6.13            | 3.1 MB    | :  82% 0.8228895374533819/1 [00:00<00:00,  4.67it/s]
#
# python-3.11.12       | 29.1 MB   | :   4% 0.038082995934981705/1 [00:00<00:05,  5.46s/it]
# numpy-1.26.4         | 7.7 MB    | :  70% 0.702819403686388/1 [00:00<00:00,  2.66it/s]
#
#
#
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
#
# python-3.11.12       | 29.1 MB   | :  15% 0.1485773221688723/1 [00:00<00:01,  1.80s/it]
#
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.30it/s]
#
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.30it/s]
#
#
#
#
# openssl-3.5.0        | 3.0 MB    | :   1% 0.005255644910358278/1 [00:00<01:10, 70.48s/it]
#
#
#
#
#
# python-3.11.12       | 29.1 MB   | :  22% 0.2247433140388357/1 [00:00<00:01,  1.58s/it]
#
#
#
#
# python-3.11.12       | 29.1 MB   | :  30% 0.29930016523549/1 [00:00<00:01,  1.53s/it]
#
#
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.36it/s]
#
#
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.36it/s]
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  3.01it/s]
#
#
#
#
# openssl-3.5.0        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# numpy-1.26.4         | 7.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.39it/s]
# python-3.11.12       | 29.1 MB   | :  40% 0.40389430900058065/1 [00:00<00:00,  1.29s/it]
#
#
#
#
#
#
# pip-25.1.1           | 1.2 MB    | :   1% 0.013181066697774328/1 [00:00<00:48, 49.50s/it]
#
#
#
#
#
#
#
# libsqlite-3.50.0     | 897 KB    | :   2% 0.01782817099113706/1 [00:00<00:36, 37.16s/it]
#
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   2% 0.018375108367605347/1 [00:00<00:35, 36.59s/it]
#
#
#
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | :   2% 0.019760996154903825/1 [00:00<00:34, 35.46s/it]
#
#
#
#
#
#
#
# libsqlite-3.50.0     | 897 KB    | : 100% 1.0/1 [00:00<00:00, 37.16s/it]
#
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:00<00:00, 36.59s/it]
#
#
#
#
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00, 49.50s/it]
#
#
#
#
#
#
#
#
#
# python-3.11.12       | 29.1 MB   | :  48% 0.48435134266603497/1 [00:00<00:00,  1.32s/it]
#
#
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   2% 0.021880692532465797/1 [00:00<00:33, 34.68s/it]
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 656 KB    | :   2% 0.02440855729694297/1 [00:00<00:30, 31.70s/it]
#
#
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:00<00:00, 34.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | :   4% 0.03619693572083467/1 [00:00<00:21, 21.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   6% 0.05800056641178136/1 [00:00<00:12, 13.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:00<00:00, 13.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:00<00:00, 21.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.12       | 29.1 MB   | :  63% 0.6345378055082164/1 [00:00<00:00,  1.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :  13% 0.1332379155552664/1 [00:00<00:05,  6.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | :  11% 0.10758915965669182/1 [00:00<00:07,  8.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :  15% 0.1451903052860118/1 [00:00<00:05,  5.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:00<00:00,  5.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.0       | 73 KB     | :  22% 0.22013516600158545/1 [00:00<00:03,  3.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.0       | 73 KB     | : 100% 1.0/1 [00:00<00:00,  3.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:00<00:00,  6.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:00<00:00,  8.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.12       | 29.1 MB   | :  78% 0.7804332265549068/1 [00:00<00:00,  1.13it/s]
#
#
# python-3.11.12       | 29.1 MB   | :  97% 0.9665571644343245/1 [00:01<00:00,  1.35it/s]
#
#
#
#
#
# python-3.11.12       | 29.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.35it/s]
#
#
#
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:01<00:00,  4.67it/s]
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:01<00:00,  3.01it/s]
#
#
#
#
# openssl-3.5.0        | 3.0 MB    | : 100% 1.0/1 [00:01<00:00,  2.44it/s]
#
#
#
#
#
#
#
# libsqlite-3.50.0     | 897 KB    | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
#
#
#
#
#
#
#
# libsqlite-3.50.0     | 897 KB    | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
# numpy-1.26.4         | 7.7 MB    | : 100% 1.0/1 [00:03<00:00,  1.39it/s]
#
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:03<00:00,  3.48s/it]
#
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:03<00:00,  3.48s/it]
#
#
#
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:03<00:00,  3.58s/it]
#
#
#
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:03<00:00,  3.58s/it]
#
#
#
#
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:03<00:00,  3.79s/it]
#
#
#
#
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:03<00:00,  3.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:04<00:00,  3.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:04<00:00,  3.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:04<00:00,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:04<00:00,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 656 KB    | : 100% 1.0/1 [00:04<00:00,  3.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 656 KB    | : 100% 1.0/1 [00:04<00:00,  3.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:04<00:00,  4.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:04<00:00,  4.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.0       | 73 KB     | : 100% 1.0/1 [00:04<00:00,  4.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.0       | 73 KB     | : 100% 1.0/1 [00:04<00:00,  4.20s/it]
#
#
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:04<00:00,  4.01s/it]
#
#
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:04<00:00,  4.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:04<00:00,  4.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:04<00:00,  4.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:04<00:00,  4.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.12       | 29.1 MB   | : 100% 1.0/1 [00:05<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate icerm
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - gwsurrogate
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astropy-base-7.1.0         |  py311h787c02d_0         9.1 MB  conda-forge
#     astropy-iers-data-0.2025.6.2.0.38.23|     pyhd8ed1ab_0         1.2 MB  conda-forge
#     bcrypt-4.3.0               |  py311h9e33e62_0         253 KB  conda-forge
#     brotli-1.1.0               |       hb9d3cd8_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hb9d3cd8_2          18 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     certifi-2025.4.26          |     pyhd8ed1ab_0         154 KB  conda-forge
#     click-8.2.1                |     pyh707e725_0          86 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     contourpy-1.3.2            |  py311hd18a35c_0         272 KB  conda-forge
#     cryptography-45.0.3        |  py311hafd3f86_0         1.6 MB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     dateparser-1.2.1           |     pyhd8ed1ab_0         170 KB  conda-forge
#     decorator-5.2.1            |     pyhd8ed1ab_0          14 KB  conda-forge
#     dqsegdb2-1.3.0             |     pyhd8ed1ab_0          28 KB  conda-forge
#     fftw-3.3.10                |nompi_hf1063bd_110         2.0 MB  conda-forge
#     fonttools-4.58.1           |  py311h2dc5d0c_0         2.8 MB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     gsl-2.7                    |       he838d99_0         3.2 MB  conda-forge
#     gwdatafind-2.0.0           |     pyh707e725_0          38 KB  conda-forge
#     gwosc-0.8.0                |     pyhd8ed1ab_0          29 KB  conda-forge
#     gwpy-3.0.12                |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     gwsurrogate-1.1.6          |  py311h7f0001c_3         226 KB  conda-forge
#     gwtools-1.1.9              |     pyhd8ed1ab_1          37 KB  conda-forge
#     h5py-3.13.0                |nompi_py311hb639ac4_100         1.3 MB  conda-forge
#     hdf5-1.14.3                |nompi_h2d575fe_109         3.7 MB  conda-forge
#     htgettoken-2.2             |  py311h38be061_0          51 KB  conda-forge
#     igwn-auth-utils-1.4.0      |     pyh707e725_0          33 KB  conda-forge
#     igwn-segments-2.1.0        |  py311h9ecbd09_0          83 KB  conda-forge
#     joblib-1.5.1               |     pyhd8ed1ab_0         219 KB  conda-forge
#     jq-1.8.0                   |       h73b1eb8_0         305 KB  conda-forge
#     kiwisolver-1.4.7           |  py311hd18a35c_0          71 KB  conda-forge
#     lalsimulation-data-6.2.0   |       ha770c72_0         3.5 MB  conda-forge
#     lcms2-2.17                 |       h717163a_0         242 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     libaec-1.1.3               |       h59595ed_0          35 KB  conda-forge
#     libasprintf-0.24.1         |       h8e693c7_0          52 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hb9d3cd8_2          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       hb9d3cd8_2          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hb9d3cd8_2         275 KB  conda-forge
#     libdeflate-1.23            |       h86f0d12_0          71 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libgettextpo-0.24.1        |       h5888daf_0         167 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_2          52 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_2          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hf1ad2bd_2         1.4 MB  conda-forge
#     libidn2-2.3.8              |       ha4ef2c3_0         135 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     liblal-7.7.0               |fftw_hcbe9c14_100         2.2 MB  conda-forge
#     liblalsimulation-6.2.0     |  py311h33ea901_0         7.6 MB  conda-forge
#     libpng-1.6.47              |       h943b412_0         282 KB  conda-forge
#     libsodium-1.0.20           |       h4ab18f5_0         201 KB  conda-forge
#     libtiff-4.7.0              |       hd9ff511_3         418 KB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     libwebp-base-1.5.0         |       h851e524_0         420 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     ligotimegps-2.0.1          |     pyhd8ed1ab_1          24 KB  conda-forge
#     matplotlib-base-3.10.3     |  py311h2b939e6_0         7.9 MB  conda-forge
#     mpmath-1.3.0               |     pyhd8ed1ab_1         429 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     numpy-2.2.6                |  py311h5d046bc_0         8.6 MB  conda-forge
#     oniguruma-6.9.10           |       hb9d3cd8_0         243 KB  conda-forge
#     openjpeg-2.5.3             |       h5fbd93e_0         335 KB  conda-forge
#     paramiko-3.5.1             |     pyhd8ed1ab_0         157 KB  conda-forge
#     pillow-11.2.1              |  py311h1322bbf_0        41.5 MB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pyerfa-2.0.1.5             |  py311h9f3472d_0         367 KB  conda-forge
#     pyjwt-2.10.1               |     pyhd8ed1ab_0          25 KB  conda-forge
#     pynacl-1.5.0               |  py311h9ecbd09_4         1.1 MB  conda-forge
#     pyparsing-3.2.3            |     pyhd8ed1ab_1          94 KB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhff2d567_1         217 KB  conda-forge
#     python-gssapi-1.9.0        |  py311h9db375c_1         598 KB  conda-forge
#     python-lal-7.7.0           |fftw_py311hb915d49_100        1001 KB  conda-forge
#     python-lalsimulation-6.2.0 |  py311h7f0001c_0         8.1 MB  conda-forge
#     pytz-2025.2                |     pyhd8ed1ab_0         185 KB  conda-forge
#     pyyaml-6.0.2               |  py311h2dc5d0c_2         208 KB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     regex-2024.11.6            |  py311h9ecbd09_0         400 KB  conda-forge
#     safe-netrc-1.0.1           |     pyhd8ed1ab_0          16 KB  conda-forge
#     scikit-learn-1.6.1         |  py311h57cc02b_0        10.2 MB  conda-forge
#     scipy-1.15.2               |  py311h8f841c2_0        16.4 MB  conda-forge
#     scitokens-1.8.1            |     pyhd8ed1ab_0          44 KB  conda-forge
#     six-1.17.0                 |     pyhd8ed1ab_0          16 KB  conda-forge
#     threadpoolctl-3.6.0        |     pyhecae5ae_0          23 KB  conda-forge
#     tzlocal-5.3                |  py311h38be061_0          40 KB  conda-forge
#     unicodedata2-16.0.0        |  py311h9ecbd09_0         396 KB  conda-forge
#     wget-1.21.4                |       hda4d442_0         752 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       149.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   astropy-base       conda-forge/linux-64::astropy-base-7.1.0-py311h787c02d_0
#   astropy-iers-data  conda-forge/noarch::astropy-iers-data-0.2025.6.2.0.38.23-pyhd8ed1ab_0
#   bcrypt             conda-forge/linux-64::bcrypt-4.3.0-py311h9e33e62_0
#   brotli             conda-forge/linux-64::brotli-1.1.0-hb9d3cd8_2
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hb9d3cd8_2
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   click              conda-forge/noarch::click-8.2.1-pyh707e725_0
#   contourpy          conda-forge/linux-64::contourpy-1.3.2-py311hd18a35c_0
#   cryptography       conda-forge/linux-64::cryptography-45.0.3-py311hafd3f86_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   dateparser         conda-forge/noarch::dateparser-1.2.1-pyhd8ed1ab_0
#   decorator          conda-forge/noarch::decorator-5.2.1-pyhd8ed1ab_0
#   dqsegdb2           conda-forge/noarch::dqsegdb2-1.3.0-pyhd8ed1ab_0
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_hf1063bd_110
#   fonttools          conda-forge/linux-64::fonttools-4.58.1-py311h2dc5d0c_0
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   gsl                conda-forge/linux-64::gsl-2.7-he838d99_0
#   gwdatafind         conda-forge/noarch::gwdatafind-2.0.0-pyh707e725_0
#   gwosc              conda-forge/noarch::gwosc-0.8.0-pyhd8ed1ab_0
#   gwpy               conda-forge/noarch::gwpy-3.0.12-pyhd8ed1ab_0
#   gwsurrogate        conda-forge/linux-64::gwsurrogate-1.1.6-py311h7f0001c_3
#   gwtools            conda-forge/noarch::gwtools-1.1.9-pyhd8ed1ab_1
#   h5py               conda-forge/linux-64::h5py-3.13.0-nompi_py311hb639ac4_100
#   hdf5               conda-forge/linux-64::hdf5-1.14.3-nompi_h2d575fe_109
#   htgettoken         conda-forge/linux-64::htgettoken-2.2-py311h38be061_0
#   igwn-auth-utils    conda-forge/noarch::igwn-auth-utils-1.4.0-pyh707e725_0
#   igwn-segments      conda-forge/linux-64::igwn-segments-2.1.0-py311h9ecbd09_0
#   joblib             conda-forge/noarch::joblib-1.5.1-pyhd8ed1ab_0
#   jq                 conda-forge/linux-64::jq-1.8.0-h73b1eb8_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.7-py311hd18a35c_0
#   lalsimulation-data conda-forge/linux-64::lalsimulation-data-6.2.0-ha770c72_0
#   lcms2              conda-forge/linux-64::lcms2-2.17-h717163a_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libaec             conda-forge/linux-64::libaec-1.1.3-h59595ed_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.24.1-h8e693c7_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-31_h59b9bed_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hb9d3cd8_2
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hb9d3cd8_2
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hb9d3cd8_2
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-31_he106b2a_openblas
#   libdeflate         conda-forge/linux-64::libdeflate-1.23-h86f0d12_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.24.1-h5888daf_0
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_2
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hf1ad2bd_2
#   libidn2            conda-forge/linux-64::libidn2-2.3.8-ha4ef2c3_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.0-hb9d3cd8_0
#   liblal             conda-forge/linux-64::liblal-7.7.0-fftw_hcbe9c14_100
#   liblalsimulation   conda-forge/linux-64::liblalsimulation-6.2.0-py311h33ea901_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-31_h7ac8fdf_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.29-pthreads_h94d23a6_0
#   libpng             conda-forge/linux-64::libpng-1.6.47-h943b412_0
#   libsodium          conda-forge/linux-64::libsodium-1.0.20-h4ab18f5_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hd9ff511_3
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.5.0-h851e524_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   ligotimegps        conda-forge/noarch::ligotimegps-2.0.1-pyhd8ed1ab_1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.10.3-py311h2b939e6_0
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_1
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/linux-64::numpy-2.2.6-py311h5d046bc_0
#   oniguruma          conda-forge/linux-64::oniguruma-6.9.10-hb9d3cd8_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.3-h5fbd93e_0
#   paramiko           conda-forge/noarch::paramiko-3.5.1-pyhd8ed1ab_0
#   pillow             conda-forge/linux-64::pillow-11.2.1-py311h1322bbf_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pyerfa             conda-forge/linux-64::pyerfa-2.0.1.5-py311h9f3472d_0
#   pyjwt              conda-forge/noarch::pyjwt-2.10.1-pyhd8ed1ab_0
#   pynacl             conda-forge/linux-64::pynacl-1.5.0-py311h9ecbd09_4
#   pyparsing          conda-forge/noarch::pyparsing-3.2.3-pyhd8ed1ab_1
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhff2d567_1
#   python-gssapi      conda-forge/linux-64::python-gssapi-1.9.0-py311h9db375c_1
#   python-lal         conda-forge/linux-64::python-lal-7.7.0-fftw_py311hb915d49_100
#   python-lalsimulat~ conda-forge/linux-64::python-lalsimulation-6.2.0-py311h7f0001c_0
#   pytz               conda-forge/noarch::pytz-2025.2-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py311h2dc5d0c_2
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   regex              conda-forge/linux-64::regex-2024.11.6-py311h9ecbd09_0
#   safe-netrc         conda-forge/noarch::safe-netrc-1.0.1-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.6.1-py311h57cc02b_0
#   scipy              conda-forge/linux-64::scipy-1.15.2-py311h8f841c2_0
#   scitokens          conda-forge/noarch::scitokens-1.8.1-pyhd8ed1ab_0
#   six                conda-forge/noarch::six-1.17.0-pyhd8ed1ab_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.6.0-pyhecae5ae_0
#   tzlocal            conda-forge/linux-64::tzlocal-5.3-py311h38be061_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-16.0.0-py311h9ecbd09_0
#   wget               conda-forge/linux-64::wget-1.21.4-hda4d442_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.4.26-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.4.26-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.0-h7b32b05_1
#
#
#
# Downloading and Extracting Packages:
# pillow-11.2.1        | 41.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
# scipy-1.15.2         | 16.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# scikit-learn-1.6.1   | 10.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# astropy-base-7.1.0   | 9.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# numpy-2.2.6          | 8.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# python-lalsimulation | 8.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# liblalsimulation-6.2 | 7.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# lalsimulation-data-6 | 3.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.58.1     | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# liblal-7.7.0         | 2.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 2.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-45.0.3  | 1.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.13.0          | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# astropy-iers-data-0. | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | :   0% 0.00037673312413117303/1 [00:00<06:00, 360.15s/it]
#
#
#
# numpy-2.2.6          | 8.6 MB    | :   0% 0.0018065944888944168/1 [00:00<01:08, 69.07s/it]
#
# scikit-learn-1.6.1   | 10.2 MB   | :   0% 0.0015245176191396935/1 [00:00<01:38, 98.54s/it]
# scipy-1.15.2         | 16.4 MB   | :   0% 0.0009529389827073913/1 [00:00<03:22, 202.95s/it]
#
#
# pillow-11.2.1        | 41.5 MB   | :  10% 0.09569021352931795/1 [00:00<00:01,  2.04s/it]
#
#
#
# numpy-2.2.6          | 8.6 MB    | :  39% 0.39203100409008845/1 [00:00<00:00,  1.99it/s]
#
# scikit-learn-1.6.1   | 10.2 MB   | :  26% 0.26374154811116696/1 [00:00<00:00,  1.28it/s]
# scipy-1.15.2         | 16.4 MB   | :  18% 0.18201134569711175/1 [00:00<00:01,  1.35s/it]
#
#
# pillow-11.2.1        | 41.5 MB   | :  18% 0.18007843333470072/1 [00:00<00:01,  1.57s/it]
#
#
#
# numpy-2.2.6          | 8.6 MB    | :  89% 0.8906510830249476/1 [00:00<00:00,  3.19it/s]
#
# scikit-learn-1.6.1   | 10.2 MB   | :  66% 0.6555425762300682/1 [00:00<00:00,  2.36it/s]
# scipy-1.15.2         | 16.4 MB   | :  42% 0.41834021340854477/1 [00:00<00:00,  1.32it/s]
#
#
# pillow-11.2.1        | 41.5 MB   | :  28% 0.28254984309837977/1 [00:00<00:00,  1.28s/it]
# pillow-11.2.1        | 41.5 MB   | :  37% 0.37183559351746776/1 [00:00<00:00,  1.24s/it]
# pillow-11.2.1        | 41.5 MB   | :  47% 0.46865600641917926/1 [00:00<00:00,  1.20s/it]
#
#
#
# numpy-2.2.6          | 8.6 MB    | : 100% 1.0/1 [00:00<00:00,  3.19it/s]
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | :  55% 0.5545511587210867/1 [00:00<00:00,  1.25s/it]
#
# scikit-learn-1.6.1   | 10.2 MB   | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
#
# scikit-learn-1.6.1   | 10.2 MB   | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
#
#
# astropy-base-7.1.0   | 9.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
#
#
# astropy-base-7.1.0   | 9.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | :  64% 0.6419532435195189/1 [00:00<00:00,  1.22s/it]
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :   0% 0.0019734725492305157/1 [00:00<07:16, 437.00s/it]
#
#
#
#
#
#
# liblalsimulation-6.2 | 7.6 MB    | :   0% 0.002066005496149631/1 [00:00<07:06, 427.41s/it]
#
#
#
#
# python-lalsimulation | 8.1 MB    | :  81% 0.8070297411129279/1 [00:00<00:00,  1.22it/s]
#
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | :  73% 0.7252112639525081/1 [00:00<00:00,  1.30s/it]
#
#
#
#
#
#
# liblalsimulation-6.2 | 7.6 MB    | :  50% 0.4979073245720611/1 [00:01<00:00,  1.48s/it]
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :  70% 0.7025562275260635/1 [00:01<00:00,  1.03s/it]
#
#
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | :  80% 0.803571753771792/1 [00:01<00:00,  1.73s/it]
#
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | :  93% 0.933921414721178/1 [00:01<00:00,  1.72s/it]
#
#
#
#
# python-lalsimulation | 8.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.22it/s]
# scipy-1.15.2         | 16.4 MB   | : 100% 1.0/1 [00:01<00:00,  1.86it/s]
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0.004168874001991818/1 [00:01<05:54, 355.96s/it]
#
#
#
#
#
#
#
#
# lalsimulation-data-6 | 3.5 MB    | :   0% 0.004426623394693833/1 [00:01<05:42, 344.14s/it]
#
#
#
#
#
#
# liblalsimulation-6.2 | 7.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.03s/it]
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :  71% 0.7087085803386091/1 [00:01<00:00,  1.63s/it]
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.22it/s]
#
#
#
#
#
#
#
#
# lalsimulation-data-6 | 3.5 MB    | :  58% 0.5798876647048922/1 [00:01<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | :   0% 0.00485247257230507/1 [00:01<05:39, 341.12s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.58.1     | 2.8 MB    | :   1% 0.00568038803041282/1 [00:01<04:58, 300.56s/it]
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
# lalsimulation-data-6 | 3.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.24s/it]
#
#
#
#
#
#
#
#
# lalsimulation-data-6 | 3.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblal-7.7.0         | 2.2 MB    | :   1% 0.007104176522136161/1 [00:01<04:19, 261.28s/it]
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.38s/it]
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.38s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.58.1     | 2.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.58.1     | 2.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 2.0 MB    | :   1% 0.00789525296951432/1 [00:01<03:59, 241.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-45.0.3  | 1.6 MB    | :   1% 0.00983917063670556/1 [00:01<03:15, 197.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   1% 0.011206734985068174/1 [00:01<02:52, 174.10s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblal-7.7.0         | 2.2 MB    | : 100% 1.0/1 [00:02<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblal-7.7.0         | 2.2 MB    | : 100% 1.0/1 [00:02<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:02<00:00, 174.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-45.0.3  | 1.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-45.0.3  | 1.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 2.0 MB    | : 100% 1.0/1 [00:02<00:00,  1.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 2.0 MB    | : 100% 1.0/1 [00:02<00:00,  1.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | :   1% 0.011429878976110548/1 [00:02<03:00, 182.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.13.0          | 1.3 MB    | :   1% 0.011684262473720394/1 [00:02<02:58, 181.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# astropy-iers-data-0. | 1.2 MB    | :   1% 0.013573307375266658/1 [00:02<02:35, 157.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | : 100% 1.0/1 [00:02<00:00, 182.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# astropy-iers-data-0. | 1.2 MB    | : 100% 1.0/1 [00:02<00:00, 157.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.13.0          | 1.3 MB    | : 100% 1.0/1 [00:02<00:00,  1.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.13.0          | 1.3 MB    | : 100% 1.0/1 [00:02<00:00,  1.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | : 100% 1.0/1 [00:03<00:00,  7.96s/it]
#
#
#
# numpy-2.2.6          | 8.6 MB    | : 100% 1.0/1 [00:04<00:00,  3.19it/s]
#
# scikit-learn-1.6.1   | 10.2 MB   | : 100% 1.0/1 [00:04<00:00,  1.23it/s]
#
#
#
#
# python-lalsimulation | 8.1 MB    | : 100% 1.0/1 [00:04<00:00,  1.22it/s]
#
#
# astropy-base-7.1.0   | 9.1 MB    | : 100% 1.0/1 [00:06<00:00,  1.37it/s]
# scipy-1.15.2         | 16.4 MB   | : 100% 1.0/1 [00:06<00:00,  1.86it/s]
#
#
#
#
#
#
# liblalsimulation-6.2 | 7.6 MB    | : 100% 1.0/1 [00:06<00:00,  1.03s/it]
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:07<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
# lalsimulation-data-6 | 3.5 MB    | : 100% 1.0/1 [00:07<00:00,  1.24s/it]
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | : 100% 1.0/1 [00:07<00:00,  1.22it/s]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.58.1     | 2.8 MB    | : 100% 1.0/1 [00:07<00:00,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
#
# liblal-7.7.0         | 2.2 MB    | : 100% 1.0/1 [00:07<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:08<00:00,  7.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:08<00:00,  7.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-45.0.3  | 1.6 MB    | : 100% 1.0/1 [00:08<00:00,  1.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# fftw-3.3.10          | 2.0 MB    | : 100% 1.0/1 [00:08<00:00,  1.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | : 100% 1.0/1 [00:08<00:00,  8.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | : 100% 1.0/1 [00:08<00:00,  8.11s/it]
#
#
#
#
#
#
#
#
#
# gsl-2.7              | 3.2 MB    | : 100% 1.0/1 [00:08<00:00,  1.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# astropy-iers-data-0. | 1.2 MB    | : 100% 1.0/1 [00:08<00:00,  8.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# astropy-iers-data-0. | 1.2 MB    | : 100% 1.0/1 [00:08<00:00,  8.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.13.0          | 1.3 MB    | : 100% 1.0/1 [00:09<00:00,  1.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.2.1        | 41.5 MB   | : 100% 1.0/1 [00:12<00:00,  7.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - jupyterlab
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anyio-4.9.0                |     pyh29332c3_0         123 KB  conda-forge
#     argon2-cffi-23.1.0         |     pyhd8ed1ab_1          18 KB  conda-forge
#     argon2-cffi-bindings-21.2.0|  py311h9ecbd09_5          34 KB  conda-forge
#     arrow-1.3.0                |     pyhd8ed1ab_1          98 KB  conda-forge
#     asttokens-3.0.0            |     pyhd8ed1ab_1          28 KB  conda-forge
#     async-lru-2.0.5            |     pyh29332c3_0          17 KB  conda-forge
#     attrs-25.3.0               |     pyh71513ae_0          56 KB  conda-forge
#     babel-2.17.0               |     pyhd8ed1ab_0         6.6 MB  conda-forge
#     beautifulsoup4-4.13.4      |     pyha770c72_0         143 KB  conda-forge
#     bleach-6.2.0               |     pyh29332c3_4         138 KB  conda-forge
#     bleach-with-css-6.2.0      |       h82add2a_4           4 KB  conda-forge
#     comm-0.2.2                 |     pyhd8ed1ab_1          12 KB  conda-forge
#     debugpy-1.8.14             |  py311hfdbb021_0         2.5 MB  conda-forge
#     defusedxml-0.7.1           |     pyhd8ed1ab_0          23 KB  conda-forge
#     exceptiongroup-1.3.0       |     pyhd8ed1ab_0          21 KB  conda-forge
#     executing-2.2.0            |     pyhd8ed1ab_0          29 KB  conda-forge
#     fqdn-1.5.1                 |     pyhd8ed1ab_1          16 KB  conda-forge
#     h11-0.16.0                 |     pyhd8ed1ab_0          37 KB  conda-forge
#     httpcore-1.0.9             |     pyh29332c3_0          48 KB  conda-forge
#     httpx-0.28.1               |     pyhd8ed1ab_0          62 KB  conda-forge
#     importlib-metadata-8.7.0   |     pyhe01879c_1          34 KB  conda-forge
#     importlib_resources-6.5.2  |     pyhd8ed1ab_0          33 KB  conda-forge
#     ipykernel-6.29.5           |     pyh3099207_0         116 KB  conda-forge
#     ipython-9.3.0              |     pyhfa0c392_0         607 KB  conda-forge
#     ipython_pygments_lexers-1.1.1|     pyhd8ed1ab_0          14 KB  conda-forge
#     isoduration-20.11.0        |     pyhd8ed1ab_1          19 KB  conda-forge
#     jedi-0.19.2                |     pyhd8ed1ab_1         824 KB  conda-forge
#     jinja2-3.1.6               |     pyhd8ed1ab_0         110 KB  conda-forge
#     json5-0.12.0               |     pyhd8ed1ab_0          33 KB  conda-forge
#     jsonschema-4.24.0          |     pyhd8ed1ab_0          73 KB  conda-forge
#     jsonschema-specifications-2025.4.1|     pyh29332c3_0          19 KB  conda-forge
#     jsonschema-with-format-nongpl-4.24.0|       hd8ed1ab_0           8 KB  conda-forge
#     jupyter-lsp-2.2.5          |     pyhe01879c_2          56 KB  conda-forge
#     jupyter_client-8.6.3       |     pyhd8ed1ab_1         104 KB  conda-forge
#     jupyter_core-5.8.1         |     pyh31011fe_0          58 KB  conda-forge
#     jupyter_events-0.12.0      |     pyh29332c3_0          23 KB  conda-forge
#     jupyter_server-2.16.0      |     pyhe01879c_0         336 KB  conda-forge
#     jupyter_server_terminals-0.5.3|     pyhd8ed1ab_1          19 KB  conda-forge
#     jupyterlab-4.4.3           |     pyhd8ed1ab_0         7.9 MB  conda-forge
#     jupyterlab_pygments-0.3.0  |     pyhd8ed1ab_2          18 KB  conda-forge
#     jupyterlab_server-2.27.3   |     pyhd8ed1ab_1          48 KB  conda-forge
#     markupsafe-3.0.2           |  py311h2dc5d0c_1          25 KB  conda-forge
#     matplotlib-inline-0.1.7    |     pyhd8ed1ab_1          14 KB  conda-forge
#     mistune-3.1.3              |     pyh29332c3_0          71 KB  conda-forge
#     nbclient-0.10.2            |     pyhd8ed1ab_0          27 KB  conda-forge
#     nbconvert-core-7.16.6      |     pyh29332c3_0         196 KB  conda-forge
#     nbformat-5.10.4            |     pyhd8ed1ab_1          99 KB  conda-forge
#     nest-asyncio-1.6.0         |     pyhd8ed1ab_1          11 KB  conda-forge
#     notebook-shim-0.2.4        |     pyhd8ed1ab_1          16 KB  conda-forge
#     overrides-7.7.0            |     pyhd8ed1ab_1          29 KB  conda-forge
#     pandocfilters-1.5.0        |     pyhd8ed1ab_0          11 KB  conda-forge
#     parso-0.8.4                |     pyhd8ed1ab_1          74 KB  conda-forge
#     pexpect-4.9.0              |     pyhd8ed1ab_1          52 KB  conda-forge
#     pickleshare-0.7.5          |  pyhd8ed1ab_1004          11 KB  conda-forge
#     pkgutil-resolve-name-1.3.10|     pyhd8ed1ab_2          10 KB  conda-forge
#     prometheus_client-0.22.1   |     pyhd8ed1ab_0          51 KB  conda-forge
#     prompt-toolkit-3.0.51      |     pyha770c72_0         265 KB  conda-forge
#     psutil-7.0.0               |  py311h9ecbd09_0         473 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd8ed1ab_1          19 KB  conda-forge
#     pure_eval-0.2.3            |     pyhd8ed1ab_1          16 KB  conda-forge
#     pygments-2.19.1            |     pyhd8ed1ab_0         868 KB  conda-forge
#     python-fastjsonschema-2.21.1|     pyhd8ed1ab_0         221 KB  conda-forge
#     python-json-logger-2.0.7   |     pyhd8ed1ab_0          13 KB  conda-forge
#     pyzmq-26.4.0               |  py311h7deb3e3_0         381 KB  conda-forge
#     referencing-0.36.2         |     pyh29332c3_0          50 KB  conda-forge
#     rfc3339-validator-0.1.4    |     pyhd8ed1ab_1          10 KB  conda-forge
#     rfc3986-validator-0.1.1    |     pyh9f0ad1d_0           8 KB  conda-forge
#     rpds-py-0.25.1             |  py311hdae7d1d_0         380 KB  conda-forge
#     send2trash-1.8.3           |     pyh0d859eb_1          22 KB  conda-forge
#     sniffio-1.3.1              |     pyhd8ed1ab_1          15 KB  conda-forge
#     soupsieve-2.7              |     pyhd8ed1ab_0          37 KB  conda-forge
#     stack_data-0.6.3           |     pyhd8ed1ab_1          26 KB  conda-forge
#     terminado-0.18.1           |     pyh0d859eb_0          22 KB  conda-forge
#     tinycss2-1.4.0             |     pyhd8ed1ab_0          28 KB  conda-forge
#     tomli-2.2.1                |     pyhd8ed1ab_1          19 KB  conda-forge
#     tornado-6.5.1              |  py311h9ecbd09_0         849 KB  conda-forge
#     traitlets-5.14.3           |     pyhd8ed1ab_1         107 KB  conda-forge
#     types-python-dateutil-2.9.0.20250516|     pyhd8ed1ab_0          22 KB  conda-forge
#     typing-extensions-4.13.2   |       h0e9735f_0          88 KB  conda-forge
#     typing_extensions-4.13.2   |     pyh29332c3_0          51 KB  conda-forge
#     typing_utils-0.1.0         |     pyhd8ed1ab_1          15 KB  conda-forge
#     uri-template-1.3.0         |     pyhd8ed1ab_1          23 KB  conda-forge
#     wcwidth-0.2.13             |     pyhd8ed1ab_1          32 KB  conda-forge
#     webcolors-24.11.1          |     pyhd8ed1ab_0          18 KB  conda-forge
#     webencodings-0.5.1         |     pyhd8ed1ab_3          15 KB  conda-forge
#     websocket-client-1.8.0     |     pyhd8ed1ab_1          46 KB  conda-forge
#     zeromq-4.3.5               |       h3b0a872_7         328 KB  conda-forge
#     zipp-3.22.0                |     pyhd8ed1ab_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        25.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   anyio              conda-forge/noarch::anyio-4.9.0-pyh29332c3_0
#   argon2-cffi        conda-forge/noarch::argon2-cffi-23.1.0-pyhd8ed1ab_1
#   argon2-cffi-bindi~ conda-forge/linux-64::argon2-cffi-bindings-21.2.0-py311h9ecbd09_5
#   arrow              conda-forge/noarch::arrow-1.3.0-pyhd8ed1ab_1
#   asttokens          conda-forge/noarch::asttokens-3.0.0-pyhd8ed1ab_1
#   async-lru          conda-forge/noarch::async-lru-2.0.5-pyh29332c3_0
#   attrs              conda-forge/noarch::attrs-25.3.0-pyh71513ae_0
#   babel              conda-forge/noarch::babel-2.17.0-pyhd8ed1ab_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.13.4-pyha770c72_0
#   bleach             conda-forge/noarch::bleach-6.2.0-pyh29332c3_4
#   bleach-with-css    conda-forge/noarch::bleach-with-css-6.2.0-h82add2a_4
#   comm               conda-forge/noarch::comm-0.2.2-pyhd8ed1ab_1
#   debugpy            conda-forge/linux-64::debugpy-1.8.14-py311hfdbb021_0
#   defusedxml         conda-forge/noarch::defusedxml-0.7.1-pyhd8ed1ab_0
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.3.0-pyhd8ed1ab_0
#   executing          conda-forge/noarch::executing-2.2.0-pyhd8ed1ab_0
#   fqdn               conda-forge/noarch::fqdn-1.5.1-pyhd8ed1ab_1
#   h11                conda-forge/noarch::h11-0.16.0-pyhd8ed1ab_0
#   httpcore           conda-forge/noarch::httpcore-1.0.9-pyh29332c3_0
#   httpx              conda-forge/noarch::httpx-0.28.1-pyhd8ed1ab_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.7.0-pyhe01879c_1
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.5.2-pyhd8ed1ab_0
#   ipykernel          conda-forge/noarch::ipykernel-6.29.5-pyh3099207_0
#   ipython            conda-forge/noarch::ipython-9.3.0-pyhfa0c392_0
#   ipython_pygments_~ conda-forge/noarch::ipython_pygments_lexers-1.1.1-pyhd8ed1ab_0
#   isoduration        conda-forge/noarch::isoduration-20.11.0-pyhd8ed1ab_1
#   jedi               conda-forge/noarch::jedi-0.19.2-pyhd8ed1ab_1
#   jinja2             conda-forge/noarch::jinja2-3.1.6-pyhd8ed1ab_0
#   json5              conda-forge/noarch::json5-0.12.0-pyhd8ed1ab_0
#   jsonschema         conda-forge/noarch::jsonschema-4.24.0-pyhd8ed1ab_0
#   jsonschema-specif~ conda-forge/noarch::jsonschema-specifications-2025.4.1-pyh29332c3_0
#   jsonschema-with-f~ conda-forge/noarch::jsonschema-with-format-nongpl-4.24.0-hd8ed1ab_0
#   jupyter-lsp        conda-forge/noarch::jupyter-lsp-2.2.5-pyhe01879c_2
#   jupyter_client     conda-forge/noarch::jupyter_client-8.6.3-pyhd8ed1ab_1
#   jupyter_core       conda-forge/noarch::jupyter_core-5.8.1-pyh31011fe_0
#   jupyter_events     conda-forge/noarch::jupyter_events-0.12.0-pyh29332c3_0
#   jupyter_server     conda-forge/noarch::jupyter_server-2.16.0-pyhe01879c_0
#   jupyter_server_te~ conda-forge/noarch::jupyter_server_terminals-0.5.3-pyhd8ed1ab_1
#   jupyterlab         conda-forge/noarch::jupyterlab-4.4.3-pyhd8ed1ab_0
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygments-0.3.0-pyhd8ed1ab_2
#   jupyterlab_server  conda-forge/noarch::jupyterlab_server-2.27.3-pyhd8ed1ab_1
#   markupsafe         conda-forge/linux-64::markupsafe-3.0.2-py311h2dc5d0c_1
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.7-pyhd8ed1ab_1
#   mistune            conda-forge/noarch::mistune-3.1.3-pyh29332c3_0
#   nbclient           conda-forge/noarch::nbclient-0.10.2-pyhd8ed1ab_0
#   nbconvert-core     conda-forge/noarch::nbconvert-core-7.16.6-pyh29332c3_0
#   nbformat           conda-forge/noarch::nbformat-5.10.4-pyhd8ed1ab_1
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.6.0-pyhd8ed1ab_1
#   notebook-shim      conda-forge/noarch::notebook-shim-0.2.4-pyhd8ed1ab_1
#   overrides          conda-forge/noarch::overrides-7.7.0-pyhd8ed1ab_1
#   pandocfilters      conda-forge/noarch::pandocfilters-1.5.0-pyhd8ed1ab_0
#   parso              conda-forge/noarch::parso-0.8.4-pyhd8ed1ab_1
#   pexpect            conda-forge/noarch::pexpect-4.9.0-pyhd8ed1ab_1
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-pyhd8ed1ab_1004
#   pkgutil-resolve-n~ conda-forge/noarch::pkgutil-resolve-name-1.3.10-pyhd8ed1ab_2
#   prometheus_client  conda-forge/noarch::prometheus_client-0.22.1-pyhd8ed1ab_0
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.51-pyha770c72_0
#   psutil             conda-forge/linux-64::psutil-7.0.0-py311h9ecbd09_0
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd8ed1ab_1
#   pure_eval          conda-forge/noarch::pure_eval-0.2.3-pyhd8ed1ab_1
#   pygments           conda-forge/noarch::pygments-2.19.1-pyhd8ed1ab_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonschema-2.21.1-pyhd8ed1ab_0
#   python-json-logger conda-forge/noarch::python-json-logger-2.0.7-pyhd8ed1ab_0
#   pyzmq              conda-forge/linux-64::pyzmq-26.4.0-py311h7deb3e3_0
#   referencing        conda-forge/noarch::referencing-0.36.2-pyh29332c3_0
#   rfc3339-validator  conda-forge/noarch::rfc3339-validator-0.1.4-pyhd8ed1ab_1
#   rfc3986-validator  conda-forge/noarch::rfc3986-validator-0.1.1-pyh9f0ad1d_0
#   rpds-py            conda-forge/linux-64::rpds-py-0.25.1-py311hdae7d1d_0
#   send2trash         conda-forge/noarch::send2trash-1.8.3-pyh0d859eb_1
#   sniffio            conda-forge/noarch::sniffio-1.3.1-pyhd8ed1ab_1
#   soupsieve          conda-forge/noarch::soupsieve-2.7-pyhd8ed1ab_0
#   stack_data         conda-forge/noarch::stack_data-0.6.3-pyhd8ed1ab_1
#   terminado          conda-forge/noarch::terminado-0.18.1-pyh0d859eb_0
#   tinycss2           conda-forge/noarch::tinycss2-1.4.0-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.2.1-pyhd8ed1ab_1
#   tornado            conda-forge/linux-64::tornado-6.5.1-py311h9ecbd09_0
#   traitlets          conda-forge/noarch::traitlets-5.14.3-pyhd8ed1ab_1
#   types-python-date~ conda-forge/noarch::types-python-dateutil-2.9.0.20250516-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.13.2-h0e9735f_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.13.2-pyh29332c3_0
#   typing_utils       conda-forge/noarch::typing_utils-0.1.0-pyhd8ed1ab_1
#   uri-template       conda-forge/noarch::uri-template-1.3.0-pyhd8ed1ab_1
#   wcwidth            conda-forge/noarch::wcwidth-0.2.13-pyhd8ed1ab_1
#   webcolors          conda-forge/noarch::webcolors-24.11.1-pyhd8ed1ab_0
#   webencodings       conda-forge/noarch::webencodings-0.5.1-pyhd8ed1ab_3
#   websocket-client   conda-forge/noarch::websocket-client-1.8.0-pyhd8ed1ab_1
#   zeromq             conda-forge/linux-64::zeromq-4.3.5-h3b0a872_7
#   zipp               conda-forge/noarch::zipp-3.22.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# jupyterlab-4.4.3     | 7.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
# babel-2.17.0         | 6.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# debugpy-1.8.14       | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pygments-2.19.1      | 868 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# tornado-6.5.1        | 849 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# jedi-0.19.2          | 824 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ipython-9.3.0        | 607 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# psutil-7.0.0         | 473 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# pyzmq-26.4.0         | 381 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# rpds-py-0.25.1       | 380 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# jupyter_server-2.16. | 336 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 328 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.5 | 265 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# python-fastjsonschem | 221 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbconvert-core-7.16. | 196 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# beautifulsoup4-4.13. | 143 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bleach-6.2.0         | 138 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# anyio-4.9.0          | 123 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 116 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# pygments-2.19.1      | 868 KB    | :   2% 0.018437992347512942/1 [00:00<00:05,  5.77s/it]
#
#
#
# jupyterlab-4.4.3     | 7.9 MB    | :   0% 0.0019890802118690933/1 [00:00<01:06, 67.02s/it]
#
# debugpy-1.8.14       | 2.5 MB    | :   1% 0.006341165870408615/1 [00:00<00:21, 21.36s/it]
#
#
#
# tornado-6.5.1        | 849 KB    | : 100% 1.0/1 [00:00<00:00,  6.21s/it]
#
#
# pygments-2.19.1      | 868 KB    | : 100% 1.0/1 [00:00<00:00,  5.43it/s]
#
#
# jupyterlab-4.4.3     | 7.9 MB    | :  32% 0.3182528338990549/1 [00:00<00:00,  1.64it/s]
#
# debugpy-1.8.14       | 2.5 MB    | :  97% 0.9701983781725181/1 [00:00<00:00,  4.97it/s]
#
#
#
#
# jedi-0.19.2          | 824 KB    | :   2% 0.019420467826552844/1 [00:00<00:13, 13.65s/it]
#
#
#
#
#
# ipython-9.3.0        | 607 KB    | :   3% 0.026346808520902647/1 [00:00<00:09, 10.24s/it]
# babel-2.17.0         | 6.6 MB    | :   0% 0.0023614003288434443/1 [00:00<02:09, 130.30s/it]
#
# debugpy-1.8.14       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  4.97it/s]
#
#
#
#
#
# jupyterlab-4.4.3     | 7.9 MB    | :  66% 0.6583855501286698/1 [00:00<00:00,  2.35it/s]
#
#
#
#
# jedi-0.19.2          | 824 KB    | : 100% 1.0/1 [00:00<00:00, 13.65s/it]
#
#
#
#
#
#
#
#
# rpds-py-0.25.1       | 380 KB    | :   4% 0.042106020616119226/1 [00:00<00:08,  8.95s/it]
#
#
#
#
#
#
#
# pyzmq-26.4.0         | 381 KB    | :   4% 0.04197344892427666/1 [00:00<00:08,  9.03s/it]
#
#
#
#
#
#
# psutil-7.0.0         | 473 KB    | :   3% 0.033796913226260265/1 [00:00<00:11, 11.40s/it]
#
#
#
#
#
#
#
# pyzmq-26.4.0         | 381 KB    | : 100% 1.0/1 [00:00<00:00,  9.03s/it]
#
#
#
#
#
#
# psutil-7.0.0         | 473 KB    | : 100% 1.0/1 [00:00<00:00, 11.40s/it]
#
#
#
#
#
#
#
#
# rpds-py-0.25.1       | 380 KB    | : 100% 1.0/1 [00:00<00:00,  8.95s/it]
# babel-2.17.0         | 6.6 MB    | :  11% 0.10862441512679843/1 [00:00<00:02,  3.12s/it]
#
#
#
#
#
#
#
#
#
# jupyter_server-2.16. | 336 KB    | :   5% 0.04757590540571933/1 [00:00<00:09,  9.56s/it]
#
#
#
#
#
#
#
#
#
# jupyter_server-2.16. | 336 KB    | : 100% 1.0/1 [00:00<00:00,  9.56s/it]
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 328 KB    | :   5% 0.04884913536076327/1 [00:00<00:09,  9.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.5 | 265 KB    | :   6% 0.060270525785293606/1 [00:00<00:07,  8.07s/it]
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 328 KB    | : 100% 1.0/1 [00:00<00:00,  9.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.5 | 265 KB    | : 100% 1.0/1 [00:00<00:00,  8.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-fastjsonschem | 221 KB    | :   7% 0.07241258911247729/1 [00:00<00:06,  7.12s/it]
# babel-2.17.0         | 6.6 MB    | :  51% 0.510062471030184/1 [00:00<00:00,  1.40it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# python-fastjsonschem | 221 KB    | : 100% 1.0/1 [00:00<00:00,  7.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# beautifulsoup4-4.13. | 143 KB    | :  11% 0.11174998124313669/1 [00:00<00:04,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# beautifulsoup4-4.13. | 143 KB    | : 100% 1.0/1 [00:00<00:00,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbconvert-core-7.16. | 196 KB    | :   8% 0.08167456792339021/1 [00:00<00:06,  6.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbconvert-core-7.16. | 196 KB    | : 100% 1.0/1 [00:00<00:00,  6.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bleach-6.2.0         | 138 KB    | :  12% 0.11586577560906616/1 [00:00<00:04,  4.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab-4.4.3     | 7.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# anyio-4.9.0          | 123 KB    | :  13% 0.12967565257309294/1 [00:00<00:04,  4.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# anyio-4.9.0          | 123 KB    | : 100% 1.0/1 [00:00<00:00,  4.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 116 KB    | :  14% 0.13758355446575526/1 [00:00<00:03,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 116 KB    | : 100% 1.0/1 [00:00<00:00,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# babel-2.17.0         | 6.6 MB    | :  71% 0.7131428993107202/1 [00:00<00:00,  1.41it/s]
#
#
#
# tornado-6.5.1        | 849 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
#
#
#
# tornado-6.5.1        | 849 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
# babel-2.17.0         | 6.6 MB    | :  96% 0.9587285335104384/1 [00:00<00:00,  1.64it/s]
#
#
# pygments-2.19.1      | 868 KB    | : 100% 1.0/1 [00:00<00:00,  5.43it/s]
# babel-2.17.0         | 6.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.64it/s]
#
#
#
#
#
# ipython-9.3.0        | 607 KB    | : 100% 1.0/1 [00:01<00:00,  1.10s/it]
#
#
#
#
#
# ipython-9.3.0        | 607 KB    | : 100% 1.0/1 [00:01<00:00,  1.10s/it]
#
# debugpy-1.8.14       | 2.5 MB    | : 100% 1.0/1 [00:01<00:00,  4.97it/s]
#
#
#
#
#
#
#
# pyzmq-26.4.0         | 381 KB    | : 100% 1.0/1 [00:01<00:00,  1.70s/it]
#
#
#
#
#
#
#
# pyzmq-26.4.0         | 381 KB    | : 100% 1.0/1 [00:01<00:00,  1.70s/it]
#
#
#
#
#
#
# psutil-7.0.0         | 473 KB    | : 100% 1.0/1 [00:01<00:00,  1.81s/it]
#
#
#
#
#
#
# psutil-7.0.0         | 473 KB    | : 100% 1.0/1 [00:01<00:00,  1.81s/it]
#
#
#
#
#
#
#
#
# rpds-py-0.25.1       | 380 KB    | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
#
#
#
#
#
#
#
#
# rpds-py-0.25.1       | 380 KB    | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
#
#
#
#
#
#
#
#
#
# jupyter_server-2.16. | 336 KB    | : 100% 1.0/1 [00:02<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
# jupyter_server-2.16. | 336 KB    | : 100% 1.0/1 [00:02<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 328 KB    | : 100% 1.0/1 [00:02<00:00,  2.11s/it]
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 328 KB    | : 100% 1.0/1 [00:02<00:00,  2.11s/it]
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.5 | 265 KB    | : 100% 1.0/1 [00:02<00:00,  2.28s/it]
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.5 | 265 KB    | : 100% 1.0/1 [00:02<00:00,  2.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-fastjsonschem | 221 KB    | : 100% 1.0/1 [00:02<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-fastjsonschem | 221 KB    | : 100% 1.0/1 [00:02<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# beautifulsoup4-4.13. | 143 KB    | : 100% 1.0/1 [00:02<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# beautifulsoup4-4.13. | 143 KB    | : 100% 1.0/1 [00:02<00:00,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbconvert-core-7.16. | 196 KB    | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbconvert-core-7.16. | 196 KB    | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bleach-6.2.0         | 138 KB    | : 100% 1.0/1 [00:02<00:00,  2.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bleach-6.2.0         | 138 KB    | : 100% 1.0/1 [00:02<00:00,  2.64s/it]
#
#
#
#
# jedi-0.19.2          | 824 KB    | : 100% 1.0/1 [00:03<00:00,  3.02s/it]
#
#
#
#
# jedi-0.19.2          | 824 KB    | : 100% 1.0/1 [00:03<00:00,  3.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# anyio-4.9.0          | 123 KB    | : 100% 1.0/1 [00:03<00:00,  3.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# anyio-4.9.0          | 123 KB    | : 100% 1.0/1 [00:03<00:00,  3.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 116 KB    | : 100% 1.0/1 [00:03<00:00,  3.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 116 KB    | : 100% 1.0/1 [00:03<00:00,  3.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab-4.4.3     | 7.9 MB    | : 100% 1.0/1 [00:04<00:00,  1.67it/s]
# babel-2.17.0         | 6.6 MB    | : 100% 1.0/1 [00:05<00:00,  1.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# Collecting forked-rompy
#   Downloading forked_rompy-0.0.3-py3-none-any.whl.metadata (2.5 kB)
# Downloading forked_rompy-0.0.3-py3-none-any.whl (40 kB)
# Installing collected packages: forked-rompy
# Successfully installed forked-rompy-0.0.3

# %%
# import the usual suspects
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Step 0: Training data from the underlying model
#
# * We need to collect training data on which to build the model
# * For simplicity, our training data will come from the generically precessing binary black hole model **NRSur7dq4**
# * **NRSur7dq4** is already fast, so a surrogate isn't needed (although it could be made faster still!). In a more realistic senario, training data would come from numerical relativity simulations.
# * To get access to **NRSur7dq4** we will use the Python package [GWSurrogate](https://github.com/sxs-collaboration/gwsurrogate), which is maintained by members of the Simulating eXtreme Spacetimes (SXS) collaboration

# %%
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")

import gwsurrogate as gws
gw_model =  gws.LoadSurrogate('NRSur7dq4')

# %%
# define a simplified interface to the NRSur7dq4 model
def NRSur7dq4_22_nonspinning(q, dt=0.1):
    """ Simplified inferface to NRSur7dq4 to get the (2,2) mode for nonspinning systems.

      INPUT
      =====
      q  -- mass ratio
      dt -- timestep size, Units of M"""

    chiA  = [0.0, 0.0, 0.0]        # dimensionless spin of the heavier BH
    chiB  = [0.0, 0.0, 0.0]        # dimensionless spin of the lighter BH
    f_low = 0.0065                 # initial frequency of wave
    f_ref = f_low                  # reference frequency the spins are defined at

    times, h, dyn = gw_model(q, chiA, chiB, dt=dt, f_low=f_low, f_ref=f_ref)

    return times, h[(2,2)]

# %%
t, h = NRSur7dq4_22_nonspinning(2.0)

# %%
plt.plot(t,np.real(h),'r',label = "real")
plt.plot(t,np.imag(h),'k--',label = "imag")
plt.legend()

# %% [markdown]
# # Step 1: Poplulating the training set
#
# There are potentially many reasonable ways to construct a training set defined on the training region
#
# $$q \in [1, 2]$$
#
# and we will use the easiest of all: uniformly spaced grid

# %%
# global settings that control the training set
dt = 0.1
train_samples = 50 # more waveforms, better models

# %%
def training_set_generator(N,verbose=False):
    """Generate N training samples from q in [1,2]"""
    qs = np.linspace(1.0,2.0,N)
    training_data = []
    for q in qs:
        t,h = NRSur7dq4_22_nonspinning(q,dt=dt)
        training_data.append(h)
        if verbose:
            print(f"The number of time samples of h(t;{q}) is {len(h)}")
    return qs, training_data

# %%
# generating training data
qs, training_data = training_set_generator(train_samples, verbose=True)

# %% [markdown]
# ## Interlude I: preparing waveform data -- common durations
#
# * For surrogate modeling to work, we need all of the waveforms to be of the same duration/length. From whats shown above, this is not the case!
# * We need to modify our waveform data to fix this problem

# %%
def common_time_grid(training_data):
    """
    INPUT
    =====
    training_data: set of training waveforms

    OUTPUT
    ======
    training data as a numpy array, padding with zeros as
    necessary such that all waveforms are of the same length"""

    longest_waveform = 0
    for h in training_data:
        length = len(h)
        if length > longest_waveform:
            longest_waveform = length

    print(f"Maximum number of waveform time samples over training set = {longest_waveform}")

    padded_training_data = []
    for h in training_data:
        nZeros = longest_waveform - len(h)
        h_pad = np.append(h, np.zeros(nZeros))
        padded_training_data.append(h_pad)

    times = np.arange(longest_waveform)*dt

    padded_training_data = np.vstack(padded_training_data).transpose()

    return times, padded_training_data

# %%
times, training_data = common_time_grid(training_data)

# %%
plt.figure(1)
plt.plot(times,np.abs(training_data));

# %% [markdown]
# ## Interlude II: preparing waveform data -- temporal alignment
#
# * For efficient surrogate models (efficient =  admits a low-dimensional approximation space), the model should change as little as possible as the parameter is varied.
# * Unfortunately, thats not the case here! Notice the waves peak at different times.
# * A simulation-dependent time-shift will align the peaks.
#
# **Goal**: Lets align all of the waveform peaks, using the shortest waveform as the reference one.
#
# **Warning**: The code below finds the waveform peak on a discrete grid. For high accuracy models, better peak finding is needed.

# %%
def get_peak(t, h):
  """Get argument and values of t and h at maximum value of |h| on a discrete grid. """
  arg = np.argmax(np.abs(h))
  return [arg, t[arg], h[arg]]

def get_peaks(t,training_set):
    """ Find the index of each waveform's peak in the entire training set. """
    time_peak_arg = []
    for i in range(train_samples):
        [arg, t_peak, h_peak] = get_peak(times,training_set[:,i]) # i^th training sample
        time_peak_arg.append(arg)
        print("Waveform %i with t_peak = %f"%(i,t_peak))
    #print(time_peak_arg)
    return time_peak_arg

def align_peaks(times, training_set):
    """ Peak align a set of waveforms. The shortest waveform is used as the reference
    one."""

    time_peak_arg = get_peaks(times,training_set)

    min_arg = min(time_peak_arg)
    aligned_training_set=[]
    for i in range(train_samples):
        offset = time_peak_arg[i] - min_arg
        #print("offset value of %i"%offset)
        h_aligned = training_set[offset:,i]
        aligned_training_set.append(h_aligned)

    t, training_data_aligned = common_time_grid(aligned_training_set)
    return training_data_aligned

# %%
training_data_aligned = align_peaks(times, training_data)

# %%
training_data_aligned.shape

# %%
plt.figure(1)
plt.plot(times,np.abs(training_data_aligned))

plt.figure(2)
plt.plot(times,np.abs(training_data_aligned),'*')
plt.xlim([2189-20,2189+20])

# %% [markdown]
# # Step 2: Building a basis
#
# ## The snapshot matrix
#
# The matrix **training_data_aligned** has 25117 rows (the time samples) and 50 columns (parameter samples). That is, each column is a complexified waveform $h^{22}(\vec{t},q)$ sampled at some value of the mass ratio $q$.
#
# ## Finding a compact basis for the set of waveforms
#
# **Goal**: Find $n$ basis $u_i(t)$ such that (i) $n$ is small and (ii) the approximation
#
# $$h(t;q) \approx \sum_{i=1}^n  c_i (q) u_i(t)$$
#
# is accurate. Some popular options for linear dimensionality reduction (in GW modeling at least) are:
#
# * **The greedy algorithm**: Find the $n$ most important waveforms (ie matrix columns).
# * **Singular Value Decomposition** (SVD): Find the $n$ most important "modes" of the data (linear combinations over all columns)
# * Here we will use the SVD, which is already coded up in numpy.
#
# ### Background on the SVD
#
# You can think of the SVD as an algorithm that identifies the "most important" columns of a matrix. A column is "important" if the other columns of the matrix can be written as a linear combination of the important ones.
#
# Suppose you have a 25117-by-50 matrix, ${\bf A}$, and you discover that all 50 columns can be written as a linear combination of just 2 columns (up to some accuracy threshold). That would be great -- you can express any training waveform as a sum over two basis functions. This is what the SVD provides, and how it can  be used to approximate a matrix ${\bf A}$.
#
# ### Numpy implementation
#
# The numpy SVD routine will decompose the training data matrix as
#
# $$\text{training\_data\_aligned} = U S V^*$$
#
# For our purpose,
# * The most important columns (the basis) are columns of the matrix U
# * The matix $S$ is diagonal, whose entries are singluar values.
# * The $i^{th}$ singular value, $s_i$, assigns a weight to how important the $i^{th}$ column is.

# %%
# first, lets check the claim that peak-aligned training sets are easier to approximate.
# From the above discussion, faster decaying singular values means the matrix/model is easier
# to compress
u, s_no_align, vh = np.linalg.svd(training_data, full_matrices=False)
u, s, vh          = np.linalg.svd(training_data_aligned, full_matrices=False)
plt.semilogy(range(train_samples),s,'r*',label='align')
plt.semilogy(range(train_samples),s_no_align,'b+',label='no align')
plt.ylabel('singluar value')
plt.xlabel('singluar value index k')
plt.legend(loc=3)

# %%
# Top 2 singular vectors -- these are the 2 most features according to the SVD
for i in range(2):
    plt.figure(i)
    plt.plot(times,np.real(u[:,i]), label= "real")
    plt.plot(times,np.imag(u[:,i]), label= "imag")
    plt.legend()

# %% [markdown]
# ## Basis application example
#
# We can immediately use the first $n$ basis to compute
#
# $$h(t;q) \approx \sum_{i=1}^n  c_i (q) u_i(t)$$
#
#
# where $u_i(t)$ is the $i^{th}$ basis vector and $c_i (q)$ are the coefficients of the representation of $h(t;q)$ in the approximation space span$\{u_i\}_{i=1}^n$.
#
# Since $u_i$ are orthonormal, the coefficient $c_i (q)$ is found by taking the inner produce of $h(t;q)$ with $u_i$

# %%
# Decide on how many column vectors to use as the basis
basis_size = 7 # More vectors -> more accuracy but also more computational cost
basis_set  = u[:,0:basis_size]

# %%
# Select a waveform to approximate
h_i = training_data_aligned[:,10]

# compute its representation in the linear space defined by the span of the basis set
proj_coeffs = np.dot(basis_set.conjugate().transpose(), h_i)
h_approx = np.dot(basis_set, proj_coeffs.transpose())
h_approx = h_approx.transpose()

# plot the original waveform, its approximated version, and the error
plt.figure(1)
plt.plot(times,h_i,'blue',label='h')
plt.plot(times,h_approx,'r--',label='h with 7 basis')
plt.legend()

plt.figure(2)
wave_err = np.abs(h_i - h_approx)
plt.semilogy(times,wave_err)

# %% [markdown]
# # Step 3: An empirical interpolant representation
#
# As an alternative to projecting onto the basis set, an empirical interpolant can be used. The main idea is to trade the $n$ peices of information, the projection coefficients $c_i$, for direct waveform evaluations.
#
# Given $n$ basis, there (usually) exists $n$ times $\{T_i\}_{i=1}^n$ for which the set of numbers
# $$\{ c_i (q) \}_{i=1}^n \Longleftrightarrow \{ h(T_i;q) \}_{i=1}^n$$
# contains equivalent information in the sense that
#
# $$ h (t;q) \approx \sum_{i=1}^n  c_i (q) u_i(t) \approx \sum_{i}^n h(T_i;q) B_i(t)$$
#
# where $B_i(t)$ are just linear combinations of $u_i(t)$ (ie the approximation space, the span of the basis, is unchanged).

# %%
# Recommened to "pip install forked-rompy" (https://pypi.org/project/forked-rompy/)
# Original code: https://bitbucket.org/chadgalley/rompy/
import rompy as rp

# %%
eim = rp.EmpiricalInterpolant(basis_set.transpose(), verbose=True) # Note the transpose

# %%
# the most important pieces of information are the interpolation times T_i and the basis B_i
eim_indicies = eim.indices
B = eim.B

# %%
# Lets see what time the empirical inteprolation method has discovered as most important:
T_eim = times[eim_indicies]

plt.figure(1)
plt.plot(times,np.real(h_i),'k')
plt.plot(T_eim,np.zeros_like(T_eim),'r*')

plt.figure(2)
plt.plot(times,np.real(h_i),'k')
plt.plot(T_eim,np.zeros_like(T_eim),'r*')
plt.xlim([2189-50,2189+50])

# %% [markdown]
# ## Empirical interpolation application example
#
# Claim: To compute the waveform $h(t;q)$ at any time, we only need to know the waveform's value at the times $T_i$.
#
# Lets check this...

# %%
# Select a waveform to approximate
h_i = training_data_aligned[:,10]

# compute its empirical interpolant representation
h_eim =  h_i[eim_indicies]
h_approx = np.dot(B.transpose(), h_eim)

# plot the original waveform, its empirically interpolated version, and the error
plt.figure(1)
plt.plot(times,h_i,'blue')
plt.plot(times,h_approx,'r--')

plt.figure(2)
plt.semilogy(times,np.abs(h_i - h_approx),label = 'Empirical interpolant')
plt.semilogy(T_eim,np.ones_like(T_eim)*1.e-12,'r*', label = r'T_{eim} nodes') # The empirical interpolant interpolates the data. So the errors will be zero at the EIM nodes
plt.semilogy(times,wave_err,label = 'SVD error')
plt.legend()

# %% [markdown]
# # Step 4: Parametric fits
#
# We are almost ready to complete our surrogate model! If we could evaluate the few functions $h(T_i;q)$ at any q, then we would be done. So what remains is finding a way to predict their values.
#
# Here one often uses some regression/interpolation method
# - Polynomials
# - Splines (This tutorial)
# - Gaussian Process Regression
# - Deep neural networks (Lucy Thomas' tutorial)
# - Others?

# %%
# First, view the data we need to fit
h_training_eim = training_data_aligned[eim_indicies,:]

#for counter, i in enumerate(eim_indicies):
for counter, i in enumerate(eim_indicies[:2]):
    plt.figure(counter)
    plt.title("eim index %i at t[i] = %f"%(i,times[i]))
    plt.plot(qs,np.real(h_training_eim[counter,:]),'r',label='real' )
    plt.plot(qs,np.imag(h_training_eim[counter,:]),'k--',label='imag' )
    plt.legend()

# %% [markdown]
# ## Interlude: dealing with hard-to-aproximate functions
#
# Evidently, these functions have a significant amount of struture in $q$. There are a few strategies for dealing with this:
#
# 1) One could look for adventageous decompositions of the data, for example,
#
# $$h^{22}(T_i;q) = A^{22}(T_i;q) \exp\left(-\mathrm{i} \phi^{22}(T_i;q) \right)$$
#
# since the amplitude, $A$, and phase, $\phi$ are expected to be "borring" functions of $q$. **There will be examples of this later today**
#
# 2) One could align the phases at some reference time. This would happen early in the surrogate building process, say step 1 after temporal alignment
#
# 3) One could brute force it, by using splines with dense grids
#
# ... we will follow 3

# %%
from scipy.interpolate import splrep, splev

# %%
# lets first show how this works on a data piece
eim_indx = 1
h_eim_real_spline = splrep(qs, np.real(h_training_eim[eim_indx,:]),k=2) # degree 2
h_eim_imag_spline = splrep(qs, np.imag(h_training_eim[eim_indx,:]),k=2) # degree 2

# evaluate the splines on a dense reference grid
q_dense = np.linspace(min(qs),max(qs),300)

plt.figure(1)
plt.plot(qs,np.real(h_training_eim[eim_indx,:]),'b',label ='real, data')
plt.plot(q_dense,splev(q_dense,h_eim_real_spline),'r--',label ='real, spline')
plt.plot(qs,np.imag(h_training_eim[eim_indx,:]),'k',label ='imag, data')
plt.plot(q_dense,splev(q_dense,h_eim_imag_spline),'g--',label ='imag, spline')
plt.legend()

# %%
# Now find the spline interpolant for all of the coefficients
h_eim_real_spline = [splrep(qs, np.real(h_training_eim[i,:]),k=2) for i in range(len(eim_indicies))]
h_eim_imag_spline = [splrep(qs, np.imag(h_training_eim[i,:]),k=2) for i in range(len(eim_indicies))]

# %%
# The full surrogate can now be evaluated by evaluating the splines, and using the
# empirical interpolation representation

q=1.2 # mass ratio value to predict now model for

h_eim = np.array([splev(q, h_eim_real_spline[j])  \
             + 1.0j*splev(q,h_eim_imag_spline[j]) for j in range(len(eim_indicies))])
h_approx = np.dot(B.transpose(), h_eim)

# plot the original waveform, its empirically interpolated version, and the error
plt.figure(1)
plt.plot(times,np.real(h_approx),'k')
plt.plot(times,np.imag(h_approx),'r--')

# %% [markdown]
# # Step 5: Full surrogate
#
# We're basically done.
#
# Lets package up all the data to make it more user friendly. Then sanity test the model by comparing against the training data. Show its faster.

# %%
def surrogate(q):
    h_eim = np.array([splev(q, h_eim_real_spline[j])  \
             + 1.0j*splev(q,h_eim_imag_spline[j]) for j in range(len(eim_indicies))])
    h_approx = np.dot(B.transpose(), h_eim)
    return h_approx

# %%
h_surr = surrogate(q=1.5)
plt.figure(1)
plt.plot(times,np.real(h_surr),'k')
plt.plot(times,np.imag(h_surr),'r--')

# %%
# timing experiment -- NRSur7dq4 model from gwsurrogate
print(f"{train_samples} samples from NRSur7dq4 model from gwsurrogate...")
# %time qs, training_data = training_set_generator(train_samples)

print(f"{train_samples} samples from surrogate model of...")
# %time surrogate_evals = np.array([surrogate(q) for q in qs]).transpose()

# %% [markdown]
# ## How to interpret timing experiments
#
# **Note**: NRSur7dq4 is slower because its computing a lot more physics!
#
# NRSur7dq4 is a fully precessing model with $\ell \leq 4$ modes.
#
# The surrogate we just built is for the $(2,2)$ mode only, nonspinning
#
# **Punchline**: you can typically making a model faster by removing accuracy/physics

# %%
# accuracy as relative error in max norm
# here we compare the model against the training data
h_error = np.abs(training_data_aligned - surrogate_evals)
h_inf =  h_error.max(axis=0) / np.abs(training_data_aligned).max(axis=0)

# %%
plt.plot(qs,h_inf)

# %% [markdown]
# # Going further
#
# The surrogate model seems to be working well. Further directions to explore include...
#
# * How do the errors compare against testing waveforms not used to train?
# * What is the dominant source of model error? Do the errors get smaller as...
#   * the number of basis used is increased?
#   * The training set density is increased?
#   * Different order splines are used?
#   * The sampling rate dt is decreased?
# * This notebook can be used for other 1-dimensional models, e.g. different slices of the precessing parameter space.
# * Fairly straightforward extensions can be used for some higher-dimensional models too

# %% [markdown]
# # Appendix

# %% [markdown]
# ## Short exercise 1
#
# Explore the relationship between the singular value spectrum, s, and the waveform error.
#
# Task: Select some waveform from your training set to approximate. Compute the approximation error vs # of SVD basis. Plot this error along with the singular values. What do you notice?

# %%
# Select a waveform to approximate
h_i = training_data_aligned[:,10]

errors = []
bss = range(1,100)
for bs in bss:
    basis_set_local  = u[:,0:bs]

    # compute its representation in the linear space defined by the span of the basis set
    proj_coeffs = np.dot(basis_set_local.conjugate().transpose(), h_i)
    h_approx = np.dot(basis_set_local, proj_coeffs.transpose())
    h_approx = h_approx.transpose()

    wave_err = np.abs(h_i - h_approx)
    errors.append(np.sum(wave_err))

# plot the original waveform, its compressed version, and the error
plt.semilogy(bss,errors,label='wave error')
plt.semilogy(range(train_samples),s,'r*',label='singular values')
plt.legend()
